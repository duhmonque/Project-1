# %%
# %matplotlib notebook

# %%
#Dependencies
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

#Files to Load for THE YEAR 2020
public_school_path = "./uc_data1.csv"
private_school_path = "./private_school_data.csv"

#Read the data file
public_school = pd.read_csv(public_school_path)
public_school['Institution_type'] = 'Public'
public_school['Year'] = 2020
private_school = pd.read_csv(private_school_path)
private_school['Institution_type'] = 'Private'
private_school['Year'] = 2020
# Display the data table for preview
uc_data_complete_2020 = pd.concat([public_school, private_school])
uc_data_complete_2020
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 880                  YORK SCHOOL52053                  YORK SCHOOL
# 881                  YORK SCHOOL52053                  YORK SCHOOL
# 882        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 883        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 884        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App   72    46.0  26.0      NaN
# 1        Fontana          San Bernardino   Adm   61    38.0  23.0      NaN
# 2        Fontana          San Bernardino   Enr   32    18.0  14.0      NaN
# 3    Los Angeles             Los Angeles   App   66    33.0  33.0      NaN
# 4    Los Angeles             Los Angeles   Adm   41    19.0  22.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 880     Monterey                Monterey   Adm   24     7.0  17.0      NaN
# 881     Monterey                Monterey   Enr   11     NaN  10.0      NaN
# 882  Los Angeles             Los Angeles   App   10     NaN  10.0      NaN
# 883  Los Angeles             Los Angeles   Adm   10     NaN  10.0      NaN
# 884  Los Angeles             Los Angeles   Enr    3     NaN   3.0      NaN
#
#     Institution_type  Year
# 0             Public  2020
# 1             Public  2020
# 2             Public  2020
# 3             Public  2020
# 4             Public  2020
# ..               ...   ...
# 880          Private  2020
# 881          Private  2020
# 882          Private  2020
# 883          Private  2020
# 884          Private  2020
#
# [4640 rows x 11 columns]

# %%
######  I think we should ignore this. This was to see a sample of our data in a scatterplot for the year 2020 but 
#####    we can use it for reference
# year=uc_data_complete_2020["Year"]
# y = uc_data_complete_2020["Count"]
# plt.scatter(year,y)
# plt.xticks(year, rotation=90)
# plt.xlabel('Year')
# plt.ylabel('Rate')
# plt.show()

# %%
######## We can ignore this too
########See our full data for 2020 public school
#public_school.head()

# %%
######## We can ignore this too
########See our full data for 2020 private school
#private_school.head()

# %%
##Files to Load for THE YEAR 2019
public_snine_path = "./public_s_nine.csv"
private_snine_path = "./private_s_nine.csv"

#Read the data file
nine_public = pd.read_csv(public_snine_path)
nine_public['Institution_type'] = 'Public'
nine_public['Year'] = 2019

nine_private = pd.read_csv(private_snine_path)
nine_private['Institution_type'] = 'Public'
nine_private['Year'] = 2019

# Merge & Display the data table for preview
nine_data_complete = pd.concat([nine_public, nine_private])
nine_data_complete
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 910                  YORK SCHOOL52053                  YORK SCHOOL
# 911                  YORK SCHOOL52053                  YORK SCHOOL
# 912                  YORK SCHOOL52053                  YORK SCHOOL
# 913        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 914        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App   59    26.0  21.0     12.0
# 1        Fontana          San Bernardino   Adm   50    21.0  19.0     10.0
# 2        Fontana          San Bernardino   Enr   21     8.0   9.0      4.0
# 3    Los Angeles             Los Angeles   App   65    42.0  23.0      NaN
# 4    Los Angeles             Los Angeles   Adm   35    24.0  11.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 910     Monterey                Monterey   App   32    17.0  15.0      NaN
# 911     Monterey                Monterey   Adm   23    12.0  11.0      NaN
# 912     Monterey                Monterey   Enr   11     5.0   6.0      NaN
# 913  Los Angeles             Los Angeles   App    6     NaN   6.0      NaN
# 914  Los Angeles             Los Angeles   Adm    3     NaN   3.0      NaN
#
#     Institution_type  Year
# 0             Public  2019
# 1             Public  2019
# 2             Public  2019
# 3             Public  2019
# 4             Public  2019
# ..               ...   ...
# 910           Public  2019
# 911           Public  2019
# 912           Public  2019
# 913           Public  2019
# 914           Public  2019
#
# [4631 rows x 11 columns]

# %%
#Files to Load for THE YEAR 2018
public_seight_path = "./public_s_eight.csv"
private_seight_path = "./private_s_eight.csv"

#Read the data file
eight_public = pd.read_csv(public_seight_path)
eight_public['Institution_type'] = 'Public'
eight_public['Year'] = 2018

eight_private = pd.read_csv(private_seight_path)
eight_private['Institution_type'] = 'Public'
eight_private['Year'] = 2018

# Merge & Display the data table for preview
eight_data_complete = pd.concat([eight_public, eight_private])
eight_data_complete
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 918  YESHIVA UNIV HS LOS ANGELES51843  YESHIVA UNIV HS LOS ANGELES
# 919  YESHIVA UNIV HS LOS ANGELES51843  YESHIVA UNIV HS LOS ANGELES
# 920                  YORK SCHOOL52053                  YORK SCHOOL
# 921                  YORK SCHOOL52053                  YORK SCHOOL
# 922                  YORK SCHOOL52053                  YORK SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App   75    41.0  27.0      7.0
# 1        Fontana          San Bernardino   Adm   56    29.0  21.0      6.0
# 2        Fontana          San Bernardino   Enr   22    13.0   8.0      NaN
# 3    Los Angeles             Los Angeles   App   62    43.0  19.0      NaN
# 4    Los Angeles             Los Angeles   Adm   34    27.0   7.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 918  Los Angeles             Los Angeles   Adm   14    11.0   NaN      NaN
# 919  Los Angeles             Los Angeles   Enr    5     5.0   NaN      NaN
# 920     Monterey                Monterey   App   35    23.0  12.0      NaN
# 921     Monterey                Monterey   Adm   21    15.0   6.0      NaN
# 922     Monterey                Monterey   Enr   11     7.0   4.0      NaN
#
#     Institution_type  Year
# 0             Public  2018
# 1             Public  2018
# 2             Public  2018
# 3             Public  2018
# 4             Public  2018
# ..               ...   ...
# 918           Public  2018
# 919           Public  2018
# 920           Public  2018
# 921           Public  2018
# 922           Public  2018
#
# [4645 rows x 11 columns]

# %%
#Files to Load for THE YEAR 2017
public_sseven_path = "./public_s_seven.csv"
private_sseven_path = "./private_s_seven.csv"

#Read the data file
seven_public = pd.read_csv(public_sseven_path)
seven_public['Institution_type'] = 'Public'
seven_public['Year'] = 2017

seven_private = pd.read_csv(private_sseven_path)
seven_private['Institution_type'] = 'Public'
seven_private['Year'] = 2017

# Merge & Display the data table for preview
seven_data_complete = pd.concat([seven_public, seven_private])
seven_data_complete
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 906                  YORK SCHOOL52053                  YORK SCHOOL
# 907                  YORK SCHOOL52053                  YORK SCHOOL
# 908                  YORK SCHOOL52053                  YORK SCHOOL
# 909        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 910        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App   88    51.0  16.0     21.0
# 1        Fontana          San Bernardino   Adm   68    35.0  13.0     20.0
# 2        Fontana          San Bernardino   Enr   34    21.0   6.0      7.0
# 3    Los Angeles             Los Angeles   App   61    40.0  21.0      NaN
# 4    Los Angeles             Los Angeles   Adm   39    26.0  13.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 906     Monterey                Monterey   App   32    17.0  14.0      NaN
# 907     Monterey                Monterey   Adm   22    10.0  11.0      NaN
# 908     Monterey                Monterey   Enr   13     9.0   4.0      NaN
# 909  Los Angeles             Los Angeles   App    8     NaN   7.0      NaN
# 910  Los Angeles             Los Angeles   Adm    5     NaN   5.0      NaN
#
#     Institution_type  Year
# 0             Public  2017
# 1             Public  2017
# 2             Public  2017
# 3             Public  2017
# 4             Public  2017
# ..               ...   ...
# 906           Public  2017
# 907           Public  2017
# 908           Public  2017
# 909           Public  2017
# 910           Public  2017
#
# [4598 rows x 11 columns]

# %%
#Files to Load for THE YEAR 2016
public_ssix_path = "./public_s_six.csv"
private_ssix_path = "./private_s_six.csv"

#Read the data file
six_public = pd.read_csv(public_ssix_path)
six_public['Institution_type'] = 'Public'
six_public['Year'] = 2016

six_private = pd.read_csv(private_ssix_path)
six_private['Institution_type'] = 'Public'
six_private['Year'] = 2016

# Merge & Display the data table for preview
six_data_complete = pd.concat([six_public, six_private])
six_data_complete
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 911                  YORK SCHOOL52053                  YORK SCHOOL
# 912                  YORK SCHOOL52053                  YORK SCHOOL
# 913        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 914        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 915        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App  101    52.0  43.0      6.0
# 1        Fontana          San Bernardino   Adm   76    42.0  28.0      6.0
# 2        Fontana          San Bernardino   Enr   41    23.0  16.0      NaN
# 3    Los Angeles             Los Angeles   App   77    48.0  29.0      NaN
# 4    Los Angeles             Los Angeles   Adm   51    39.0  12.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 911     Monterey                Monterey   Adm   20     8.0  12.0      NaN
# 912     Monterey                Monterey   Enr    8     NaN   7.0      NaN
# 913  Los Angeles             Los Angeles   App   12     NaN  12.0      NaN
# 914  Los Angeles             Los Angeles   Adm   10     NaN  10.0      NaN
# 915  Los Angeles             Los Angeles   Enr    4     NaN   4.0      NaN
#
#     Institution_type  Year
# 0             Public  2016
# 1             Public  2016
# 2             Public  2016
# 3             Public  2016
# 4             Public  2016
# ..               ...   ...
# 911           Public  2016
# 912           Public  2016
# 913           Public  2016
# 914           Public  2016
# 915           Public  2016
#
# [4541 rows x 11 columns]

# %%
#Merging the data of all 5 years of public and private school data using concat 

All_complete_data = pd.concat([uc_data_complete_2020, nine_data_complete, eight_data_complete, seven_data_complete, six_data_complete])
All_complete_data
# Out:
#                          Calculation1                       School  \
# 0         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 1         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 2         A B MILLER HIGH SCHOOL50944       A B MILLER HIGH SCHOOL
# 3    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# 4    ABRAHAM LINCOLN HIGH SCHOOL51520  ABRAHAM LINCOLN HIGH SCHOOL
# ..                                ...                          ...
# 911                  YORK SCHOOL52053                  YORK SCHOOL
# 912                  YORK SCHOOL52053                  YORK SCHOOL
# 913        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 914        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
# 915        YULA BOYS HIGH SCHOOL51841        YULA BOYS HIGH SCHOOL
#
#             City County/State/ Territory Count  All  Female  Male  Unknown  \
# 0        Fontana          San Bernardino   App   72    46.0  26.0      NaN
# 1        Fontana          San Bernardino   Adm   61    38.0  23.0      NaN
# 2        Fontana          San Bernardino   Enr   32    18.0  14.0      NaN
# 3    Los Angeles             Los Angeles   App   66    33.0  33.0      NaN
# 4    Los Angeles             Los Angeles   Adm   41    19.0  22.0      NaN
# ..           ...                     ...   ...  ...     ...   ...      ...
# 911     Monterey                Monterey   Adm   20     8.0  12.0      NaN
# 912     Monterey                Monterey   Enr    8     NaN   7.0      NaN
# 913  Los Angeles             Los Angeles   App   12     NaN  12.0      NaN
# 914  Los Angeles             Los Angeles   Adm   10     NaN  10.0      NaN
# 915  Los Angeles             Los Angeles   Enr    4     NaN   4.0      NaN
#
#     Institution_type  Year
# 0             Public  2020
# 1             Public  2020
# 2             Public  2020
# 3             Public  2020
# 4             Public  2020
# ..               ...   ...
# 911           Public  2016
# 912           Public  2016
# 913           Public  2016
# 914           Public  2016
# 915           Public  2016
#
# [23055 rows x 11 columns]

# %%
#Finding the total number of admissions, applications, and enrollment of 2016-2020 (as a whole)

All_complete_data["Count"].value_counts()
# Out:
# Adm    7923
# App    7865
# Enr    7267
# Name: Count, dtype: int64

# %%
#Finding the number of Adm, App, Enr for EACH year (make it into series, like a list)
All_complete_data.groupby("Year")["Count"].value_counts()
# Out:
# Year  Count
# 2016  Adm      1558
#       App      1546
#       Enr      1437
# 2017  Adm      1580
#       App      1568
#       Enr      1450
# 2018  App      1594
#       Adm      1586
#       Enr      1465
# 2019  Adm      1591
#       App      1576
#       Enr      1464
# 2020  Adm      1608
#       App      1581
#       Enr      1451
# Name: Count, dtype: int64

# %%
#Convert into a dataframe (turn a series into a table, like a matrix to see the rows and columns)
df = pd.DataFrame (All_complete_data.groupby("Year")["Count"].value_counts())
df
df.rename_axis(index={"Count":"Type"}, inplace = True)

# %%
df
# Out:
#            Count
# Year Type
# 2016 Adm    1558
#      App    1546
#      Enr    1437
# 2017 Adm    1580
#      App    1568
#      Enr    1450
# 2018 App    1594
#      Adm    1586
#      Enr    1465
# 2019 Adm    1591
#      App    1576
#      Enr    1464
# 2020 Adm    1608
#      App    1581
#      Enr    1451

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Year Type  Count
# 0   2016  Adm   1558
# 1   2016  App   1546
# 2   2016  Enr   1437
# 3   2017  Adm   1580
# 4   2017  App   1568
# 5   2017  Enr   1450
# 6   2018  App   1594
# 7   2018  Adm   1586
# 8   2018  Enr   1465
# 9   2019  Adm   1591
# 10  2019  App   1576
# 11  2019  Enr   1464
# 12  2020  Adm   1608
# 13  2020  App   1581
# 14  2020  Enr   1451

# %%
##### Side note: we should make the bars a bit more cleaner maybe in percentages?
#pivot data to be able to generate each column of Adm, App, Enr in a bar graph
df.pivot("Year","Type", "Count").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#### We need to fix the settings , bascially the overall data visualization for it to be more readable.
# Generate a scatter plot of year versus Adm,App,Enr
year=df["Year"]
y = df["Count"]
plt.scatter(year,y)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
#Top 10 schools with highest application (count and percentage)
#All_complete_data or separate it by year (that will seem easier?) ---> ex.uc_data_complete_2020
#count()
#value_counts()
#list(uc_datacomplete_2020)
#.head()
uc_data_complete_2020["Count"].max()
#print("Highest application is:", max(list))
# Out:
# 'Enr'

# %%
#Top 10 schools with highest admissions (count and percentage)

# %%
#Top 10 schools highest enrollment (count and percentage)

# %%
#Bottom 10 schools with lowest application (count and percentage)

# %%
#Bottom 10 schools with lowest admissions (count and percentage)

# %%
#Bottom 10 schools lowest enrollment (count and percentage)
